# %%
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# %%
df = pd.read_csv("../input/treino_superior.csv")

# %%
df.apply(lambda x : print(x))
# Out:
# 0      /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 1      /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 2      /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 3      /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 4      /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 5      /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 6      /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 7      /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 8      /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 9      /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 10     /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 11     /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 12     /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 13     /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 14     /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# 15     /9j/4AAQSkZJRgABAQAAAQABAAD/2wBDAAgGBgcGBQgHBw...
# ...

# %%
def trocaInf(x):
    if "-Infinity" in str(x):
        print("ABEA")
        return float('nan')
    else:
        return x

# %%
df2 = df.apply(lambda x : x.apply(trocaInf))
# Out:
# ABEA
# ABEA
# ABEA
# ABEA
# ABEA
# ABEA
# ABEA
# ABEA
# ABEA
# ABEA
# ABEA
# ABEA
# ABEA
# ABEA
# ABEA
# ABEA
# ABEA
# ABEA
# ABEA
# ABEA
# ABEA
# ABEA
# ABEA
# ABEA
# ABEA
# ABEA
# ABEA
# ABEA
# ABEA
# ABEA
# ABEA
# ABEA
# ABEA
# ABEA
# ABEA
# ABEA
# ABEA
# ABEA
# ABEA
# ABEA
# ABEA
# ABEA
# ABEA
# ABEA

# %%
df2.isnull().sum()
# Out:
# image                 0
#  Hip_Center_A         0
#  Hip_Center_X         0
#  Hip_Center_Y         0
#  Hip_Center_Z         0
#  Spine_A              0
#  Spine_X              0
#  Spine_Y              0
#  Spine_Z              0
#  Shoulder_Center_A    0
#  Shoulder_Center_X    0
#  Shoulder_Center_Y    0
#  Shoulder_Center_Z    0
#  Head_A               0
#  Head_X               0
#  Head_Y               0
#  Head_Z               0
#  Shoulder_Left_A      1
#  Shoulder_Left_X      1
#  Shoulder_Left_Y      1
#  Shoulder_Left_Z      1
#  Elbow_Left_A         2
#  Elbow_Left_X         2
#  Elbow_Left_Y         2
#  Elbow_Left_Z         2
#  Wrist_Left_A         2
#  Wrist_Left_X         2
#  Wrist_Left_Y         2
#  Wrist_Left_Z         2
#  Hand_Left_A          4
#  Hand_Left_X          4
#  Hand_Left_Y          4
#  Hand_Left_Z          4
#  Shoulder_Right_A     0
#  Shoulder_Right_X     0
#  Shoulder_Right_Y     0
#  Shoulder_Right_Z     0
#  Elbow_Right_A        0
# ...

# %%
df2.to_csv("../input/treino_superior2.csv", index=False)
